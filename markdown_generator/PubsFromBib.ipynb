# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "output.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "output.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                if author.last_names[0] != 'others':
                    citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "
                else:
                    citation = citation+" others"

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename

            md += """\ncategory: """ + pubsource
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# WARNING Missing Expected Field 'booktitle' from entry Werthen_Brabants_2022: " Uncertainty quantification for ... "
# SUCESSFULLY PARSED Castillo_Escario_2022: " Convolutional Neural Networks for Apnea Detection from Smart ... "
# WARNING Missing Expected Field 'booktitle' from entry Werthen_Brabants_2022_splitbirnn: " Split {BiRNN} for real-time ac ... "
# WARNING Missing Expected Field 'booktitle' from entry Bhavanasi_2022: " Patient activity recognition u ... "
# SUCESSFULLY PARSED 9924932: " Quantifying Uncertainty in Real Time with Split BiRNN for Ra ... "
# SUCESSFULLY PARSED 9924872: " Tailoring Radar-Based Patient Monitoring Models to Real-Life ... "
# WARNING Missing Expected Field 'booktitle' from entry bhavanasi2023open: " Open-set patient activity reco ... "
# WARNING Missing Expected Field 'booktitle' from entry werthen2023reliable: " Reliable assessment of uncerta ... "
# SUCESSFULLY PARSED van2024towards: " Towards Trustworthy Neural Networks for Certification by Ana ... "
# SUCESSFULLY PARSED tuytte2024optimized: " Optimized Data Transmission for Radar-Based Edge-Cloud Human ... "
# WARNING Missing Expected Field 'booktitle' from entry 10.1371/journal.pdig.0000533: " Machine-learning-based predict ... "
# SUCESSFULLY PARSED heidari2024data: " Data-Driven Surrogate Modeling for the Flammability Reductio ... "
# WARNING Missing Expected Field 'booktitle' from entry werthen2024deep: " Deep Learning-Based Event Coun ... "
# SUCESSFULLY PARSED heidari2024optimizing: " Optimizing Memory Footprint for Radar-Based Human Activity R ... "
# WARNING Missing Expected Field 'booktitle' from entry khan2025leveraging: " Leveraging Hand-Crafted Radiom ... "
# SUCESSFULLY PARSED Werthen_Brabants_2022: " Uncertainty quantification for appliance recognition in non- ... "
# WARNING Missing Expected Field 'journal' from entry Castillo_Escario_2022: " Convolutional Neural Networks  ... "
# SUCESSFULLY PARSED Werthen_Brabants_2022_splitbirnn: " Split {BiRNN} for real-time activity recognition using radar ... "
# SUCESSFULLY PARSED Bhavanasi_2022: " Patient activity recognition using radar sensors and machine ... "
# WARNING Missing Expected Field 'journal' from entry 9924932: " Quantifying Uncertainty in Rea ... "
# WARNING Missing Expected Field 'journal' from entry 9924872: " Tailoring Radar-Based Patient  ... "
# SUCESSFULLY PARSED bhavanasi2023open: " Open-set patient activity recognition with radar sensors and ... "
# SUCESSFULLY PARSED werthen2023reliable: " Reliable assessment of uncertainty for appliance recognition ... "
# WARNING Missing Expected Field 'journal' from entry van2024towards: " Towards Trustworthy Neural Net ... "
# WARNING Missing Expected Field 'journal' from entry tuytte2024optimized: " Optimized Data Transmission fo ... "
# SUCESSFULLY PARSED 10.1371/journal.pdig.0000533: " Machine-learning-based prediction of disability progression  ... "
# WARNING Missing Expected Field 'journal' from entry heidari2024data: " Data-Driven Surrogate Modeling ... "
# SUCESSFULLY PARSED werthen2024deep: " Deep Learning-Based Event Counting for Apnea-Hypopnea Index  ... "
# WARNING Missing Expected Field 'journal' from entry heidari2024optimizing: " Optimizing Memory Footprint fo ... "
# SUCESSFULLY PARSED khan2025leveraging: " Leveraging Hand-Crafted Radiomics on Multicenter FLAIR MRI f ... "
